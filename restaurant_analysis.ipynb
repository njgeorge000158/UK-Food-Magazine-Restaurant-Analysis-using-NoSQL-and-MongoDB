# %%
#*******************************************************************************************
 #
 #  File Name:  restaurant_analysis.ipynb
 #
 #  File Description:
 #      This interactive Python notebook, restaurant_analysis.ipynb, uses the Python 
 #      module, pymongo to analyze restaurant ratings data in a MongoDB database, 
 #      uk_food, for the editors of a food magazine, Eat Safe, Love.
 #
 #
 #  Date            Description                             Programmer
 #  ----------      ------------------------------------    ------------------
 #  09/18/2023      Initial Development                     Nicholas J. George
 #
 #******************************************************************************************/

import logx
import pandasx

import restaurant_analysisx

import pandas as pd

from pprint import pprint
from pymongo import MongoClient

pd.options.mode.chained_assignment = None
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ffdef3d1-dd13-4bb5-8c16-f052ddba7875" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8ea204a6-644e-4bc2-9770-472faa52b40b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4b19df4ec806494ebaf039e680582054","client_comm_id":"7adc96cc6101465989dfa0b12a9f47a3"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"8ea204a6-644e-4bc2-9770-472faa52b40b","roots":{"p1002":"ffdef3d1-dd13-4bb5-8c16-f052ddba7875"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
CONSTANT_LOCAL_FILE_NAME = 'restaurant_analysis.ipynb'

hover_columns_string_list \
    = ['BusinessName', 'Hygiene' 'BusinessType'
       'AddressLine1', 'AddressLine2', 'AddressLine3'
       'PostCode', 'LocalAuthorityName']


logx.set_log_mode(False)

logx.set_image_mode(False)


logx.begin_program('restaurant_analysis')

# %% [markdown]
# # <br> **Section 1: Database Connection**

# %% [markdown]
# ## **1.1: MongoDB Client**

# %%
# This line of code creates an instance of a MongoDB client.
current_pymongo_client = MongoClient(port = 27017)

logx.log_write_object(current_pymongo_client)

# %% [markdown]
# ## **1.2: MongoDB Database Confirmation**

# %%
# These lines of code list all the MongoDB databases and confirm the existence 
# of the database, uk_food.
logx.print_and_log_text \
    ('\033[1mThis is a List of the current MongoDB Databases:\n\033[0m' \
     + str(current_pymongo_client.list_database_names()))

if 'uk_food' in current_pymongo_client.list_database_names():
     
    logx.print_and_log_text \
        ("\033[1m\nThe MongoDB Database, 'uk_food', is in the MongoDB database list.\033[0m")
    
else:
    
    logx.print_and_log_text \
        ('\033[1m' \
         + "\nThe MongoDB Database, 'uk_food', is NOT in the List. "
         + 'Please run NoSQLSetup.ipynb before proceeding!' \
         + '\033[0m')
# Out:
# This is a List of the current MongoDB Databases:
# ['admin', 'atlanta', 'boston', 'chicago', 'config', 'epa', 'fruits_db', 'local', 'met', 'offense_codes', 'petsitly_marketing', 'predictive_map', 'san_francisco', 'uk_food', 'washington_dc']
#
# The MongoDB Database, 'uk_food', is in the MongoDB database list.

# %% [markdown]
# ## **1.3: MongoDB Database**

# %%
# This line of code creates a PyMongo database for the database, uk_food.
current_pymongo_database = current_pymongo_client.uk_food
    
logx.print_and_log_text(str(current_pymongo_database))
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'uk_food')

# %% [markdown]
# ## **1.4: MongoDB Collection Confirmation**

# %%
# These lines of code list all the collections in the MongoDB database, uk_food, 
# and confirm the existence of the collection, establishments.
logx.print_and_log_text \
    ('\033[1m' \
     + 'Here is a List of the current collections in the MongoDB Database, uk_food:\n' \
     + '\033[0m' \
     + str(current_pymongo_database.list_collection_names()))

if 'establishments' in current_pymongo_database.list_collection_names():
     
    logx.print_and_log_text \
        ("\033[1m\nThe Collection, 'establishments', is in the MongoDB Database, 'uk_food'.\033[0m")
    
else:
    
    logx.print_and_log_text \
        ('\033[1m' \
         + "\nThe collection, 'establishments', is NOT in the MongoDB database, 'uk_food'. " \
         + 'Please run mongodb_setup.ipynb before proceeding!' \
         + '\033[0m')
# Out:
# Here is a List of the current collections in the MongoDB Database, uk_food:
# ['establishments']
#
# The Collection, 'establishments', is in the MongoDB Database, 'uk_food'.

# %% [markdown]
# ## **1.5: MongoDB Collection**

# %%
# This line of code creates a PyMongo collection for the collection, establishments.
establishments_pymongo_collection = current_pymongo_database.establishments

logx.log_write_object(establishments_pymongo_collection)

# %% [markdown]
# # <br> **Section 2: Exploratory Analysis**

# %% [markdown]
# ## **2.1 -- Which establishments have a hygiene score equal to 20 (the worst possible rating)?**

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
# These lines of code query and display the number of establishments with the lowest hygiene score, 20.
query_dictionary = {'scores.Hygiene': 20}

establishments_count_integer  = establishments_pymongo_collection.count_documents(query_dictionary)

logx.print_and_log_text \
    ('\033[1m' \
     + 'There are {:,} establishments with a hygiene score equal to 20.' \
        .format(establishments_count_integer) \
     + '\033[0m')
# Out:
# There are 41 establishments with a hygiene score equal to 20.

# %% [markdown]
# ### **Display First Document**

# %%
# This query returns all the documents where the restaurant has a hygiene score equal to 20.
query_results_dictionary_list = establishments_pymongo_collection.find(query_dictionary)

# This line of code displays the first document from the query results.
pprint(query_results_dictionary_list[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f2efc371bdca4d9e9a82e'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %% [markdown]
# ### **Worst Hygiene Establishments Data Set**

# %%
# This line of code creates the dataframe.
worst_hygiene_establishments_dataframe = pd.DataFrame(list(query_results_dictionary_list))

# This function rearranges the columns in the dataframe.
worst_hygiene_establishments_dataframe \
    = restaurant_analysisx.rearrange_establishments_dataframe_columns \
        (worst_hygiene_establishments_dataframe)

logx.log_write_object(worst_hygiene_establishments_dataframe)

# %% [markdown]
# ### **Number of Rows in Worst Hygiene Establishments Data Set**

# %%
logx.print_and_log_text \
    ('\033[1m' \
     + 'The number of rows in the Lowest Hygiene Establishments DataFrame is {:,}.' \
        .format(len(worst_hygiene_establishments_dataframe)) \
     + '\033[0m')
# Out:
# The number of rows in the Lowest Hygiene Establishments DataFrame is 41.

# %% [markdown]
# ### **Worst Hygiene Establishments' Locations Data Set**

# %%
worst_hygiene_establishments_dataframe.columns
# Out:
# Index(['_id', 'FHRSID', 'ChangesByServerID', 'LocalAuthorityBusinessID',
#        'BusinessName', 'BusinessType', 'BusinessTypeID', 'AddressLine1',
#        'AddressLine2', 'AddressLine3', 'AddressLine4', 'PostCode', 'geocode',
#        'Distance', 'Phone', 'RatingValue', 'RatingKey', 'RatingDate',
#        'NewRatingPending', 'scores', 'LocalAuthorityCode',
#        'LocalAuthorityName', 'LocalAuthorityWebSite',
#        'LocalAuthorityEmailAddress', 'SchemeType', 'RightToReply', 'meta',
#        'links'],
#       dtype='object')

# %%
worst_hygiene_locations_dataframe \
    = restaurant_analysisx.return_locations_dataframe \
        (worst_hygiene_establishments_dataframe, 'Hygiene')

logx.log_write_object(worst_hygiene_locations_dataframe)

# %% [markdown]
# ### **Display Worst Hygiene Establishments**

# %%
pandasx.return_formatted_table \
    (worst_hygiene_locations_dataframe, 'Table 2.1: Worst Hygiene Establishments') \
        .format({'RatingValue': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_3d002 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_3d002_row0_col0, #T_3d002_row0_col1, #T_3d002_row0_col2, #T_3d002_row0_col3, #T_3d002_row0_col4, #T_3d002_row0_col5, #T_3d002_row0_col6, #T_3d002_row0_col7, #T_3d002_row0_col8, #T_3d002_row0_col9, #T_3d002_row0_col10, #T_3d002_row0_col11, #T_3d002_row0_col12, #T_3d002_row0_col13, #T_3d002_row0_col14, #T_3d002_row0_col15, #T_3d002_row0_col16, #T_3d002_row1_col0, #T_3d002_row1_col1, #T_3d002_row1_col2, #T_3d002_row1_col3, #T_3d002_row1_col4, #T_3d002_row1_col5, #T_3d002_row1_col6, #T_3d002_row1_col7, #T_3d002_row1_col8, #T_3d002_row1_col9, #T_3d002_row1_col10, #T_3d002_row1_col11, #T_3d002_row1_col12, #T_3d002_row1_col13, #T_3d002_row1_col14, #T_3d002_row1_col15, #T_3d002_row1_col16, #T_3d002_row2_col0, #T_3d002_row2_col1, #T_3d002_row2_col2, #T_3d002_row2_col3, #T_3d002_row2_col4, #T_3d002_row2_col5, #T_3d002_row2_col6, #T_3d002_row2_col7, #T_3d002_row2_col8, #T_3d002_row2_col9, #T_3d002_row2_col10, #T_3d002_row2_col11, #T_3d002_row2_col12, #T_3d002_row2_col13, #T_3d002_row2_col14, #T_3d002_row2_col15, #T_3d002_row2_col16, #T_3d002_row3_col0, #T_3d002_row3_col1, #T_3d002_row3_col2, #T_3d002_row3_col3, #T_3d002_row3_col4, #T_3d002_row3_col5, #T_3d002_row3_col6, #T_3d002_row3_col7, #T_3d002_row3_col8, #T_3d002_row3_col9, #T_3d002_row3_col10, #T_3d002_row3_col11, #T_3d002_row3_col12, #T_3d002_row3_col13, #T_3d002_row3_col14, #T_3d002_row3_col15, #T_3d002_row3_col16, #T_3d002_row4_col0, #T_3d002_row4_col1, #T_3d002_row4_col2, #T_3d002_row4_col3, #T_3d002_row4_col4, #T_3d002_row4_col5, #T_3d002_row4_col6, #T_3d002_row4_col7, #T_3d002_row4_col8, #T_3d002_row4_col9, #T_3d002_row4_col10, #T_3d002_row4_col11, #T_3d002_row4_col12, #T_3d002_row4_col13, #T_3d002_row4_col14, #T_3d002_row4_col15, #T_3d002_row4_col16, #T_3d002_row5_col0, #T_3d002_row5_col1, #T_3d002_row5_col2, #T_3d002_row5_col3, #T_3d002_row5_col4, #T_3d002_row5_col5, #T_3d002_row5_col6, #T_3d002_row5_col7, #T_3d002_row5_col8, #T_3d002_row5_col9, #T_3d002_row5_col10, #T_3d002_row5_col11, #T_3d002_row5_col12, #T_3d002_row5_col13, #T_3d002_row5_col14, #T_3d002_row5_col15, #T_3d002_row5_col16, #T_3d002_row6_col0, #T_3d002_row6_col1, #T_3d002_row6_col2, #T_3d002_row6_col3, #T_3d002_row6_col4, #T_3d002_row6_col5, #T_3d002_row6_col6, #T_3d002_row6_col7, #T_3d002_row6_col8, #T_3d002_row6_col9, #T_3d002_row6_col10, #T_3d002_row6_col11, #T_3d002_row6_col12, #T_3d002_row6_col13, #T_3d002_row6_col14, #T_3d002_row6_col15, #T_3d002_row6_col16, #T_3d002_row7_col0, #T_3d002_row7_col1, #T_3d002_row7_col2, #T_3d002_row7_col3, #T_3d002_row7_col4, #T_3d002_row7_col5, #T_3d002_row7_col6, #T_3d002_row7_col7, #T_3d002_row7_col8, #T_3d002_row7_col9, #T_3d002_row7_col10, #T_3d002_row7_col11, #T_3d002_row7_col12, #T_3d002_row7_col13, #T_3d002_row7_col14, #T_3d002_row7_col15, #T_3d002_row7_col16, #T_3d002_row8_col0, #T_3d002_row8_col1, #T_3d002_row8_col2, #T_3d002_row8_col3, #T_3d002_row8_col4, #T_3d002_row8_col5, #T_3d002_row8_col6, #T_3d002_row8_col7, #T_3d002_row8_col8, #T_3d002_row8_col9, #T_3d002_row8_col10, #T_3d002_row8_col11, #T_3d002_row8_col12, #T_3d002_row8_col13, #T_3d002_row8_col14, #T_3d002_row8_col15, #T_3d002_row8_col16, #T_3d002_row9_col0, #T_3d002_row9_col1, #T_3d002_row9_col2, #T_3d002_row9_col3, #T_3d002_row9_col4, #T_3d002_row9_col5, #T_3d002_row9_col6, #T_3d002_row9_col7, #T_3d002_row9_col8, #T_3d002_row9_col9, #T_3d002_row9_col10, #T_3d002_row9_col11, #T_3d002_row9_col12, #T_3d002_row9_col13, #T_3d002_row9_col14, #T_3d002_row9_col15, #T_3d002_row9_col16 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_3d002">
#   <caption>Table 2.1: Worst Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_3d002_level0_col0" class="col_heading level0 col0" >BusinessName</th>
#       <th id="T_3d002_level0_col1" class="col_heading level0 col1" >BusinessType</th>
#       <th id="T_3d002_level0_col2" class="col_heading level0 col2" >AddressLine1</th>
#       <th id="T_3d002_level0_col3" class="col_heading level0 col3" >AddressLine2</th>
#       <th id="T_3d002_level0_col4" class="col_heading level0 col4" >AddressLine3</th>
#       <th id="T_3d002_level0_col5" class="col_heading level0 col5" >AddressLine4</th>
#       <th id="T_3d002_level0_col6" class="col_heading level0 col6" >PostCode</th>
#       <th id="T_3d002_level0_col7" class="col_heading level0 col7" >RatingValue</th>
#       <th id="T_3d002_level0_col8" class="col_heading level0 col8" >RatingDate</th>
#       <th id="T_3d002_level0_col9" class="col_heading level0 col9" >NewRatingPending</th>
#       <th id="T_3d002_level0_col10" class="col_heading level0 col10" >LocalAuthorityName</th>
#       <th id="T_3d002_level0_col11" class="col_heading level0 col11" >Latitude</th>
#       <th id="T_3d002_level0_col12" class="col_heading level0 col12" >Longitude</th>
#       <th id="T_3d002_level0_col13" class="col_heading level0 col13" >Hygiene</th>
#       <th id="T_3d002_level0_col14" class="col_heading level0 col14" >Structural</th>
#       <th id="T_3d002_level0_col15" class="col_heading level0 col15" >ConfidenceInManagement</th>
#       <th id="T_3d002_level0_col16" class="col_heading level0 col16" >MarkerSize</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3d002_row0_col0" class="data row0 col0" >The Chase Rest Home</td>
#       <td id="T_3d002_row0_col1" class="data row0 col1" >Caring Premises</td>
#       <td id="T_3d002_row0_col2" class="data row0 col2" >5-6 Southfields Road</td>
#       <td id="T_3d002_row0_col3" class="data row0 col3" >Eastbourne</td>
#       <td id="T_3d002_row0_col4" class="data row0 col4" >East Sussex</td>
#       <td id="T_3d002_row0_col5" class="data row0 col5" ></td>
#       <td id="T_3d002_row0_col6" class="data row0 col6" >BN21 1BU</td>
#       <td id="T_3d002_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_3d002_row0_col8" class="data row0 col8" >2021-09-23T00:00:00</td>
#       <td id="T_3d002_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_3d002_row0_col10" class="data row0 col10" >Eastbourne</td>
#       <td id="T_3d002_row0_col11" class="data row0 col11" >50.769705</td>
#       <td id="T_3d002_row0_col12" class="data row0 col12" >0.276940</td>
#       <td id="T_3d002_row0_col13" class="data row0 col13" >20</td>
#       <td id="T_3d002_row0_col14" class="data row0 col14" >20</td>
#       <td id="T_3d002_row0_col15" class="data row0 col15" >20</td>
#       <td id="T_3d002_row0_col16" class="data row0 col16" >100.000000</td>
#     </tr>
#     <tr>
#       <td id="T_3d002_row1_col0" class="data row1 col0" >Brenalwood</td>
#       <td id="T_3d002_row1_col1" class="data row1 col1" >Caring Premises</td>
#       <td id="T_3d002_row1_col2" class="data row1 col2" >Hall Lane</td>
#       <td id="T_3d002_row1_col3" class="data row1 col3" >Walton-on-the-Naze</td>
#       <td id="T_3d002_row1_col4" class="data row1 col4" >Essex</td>
#       <td id="T_3d002_row1_col5" class="data row1 col5" ></td>
#       <td id="T_3d002_row1_col6" class="data row1 col6" >CO14 8HN</td>
#       <td id="T_3d002_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_3d002_row1_col8" class="data row1 col8" >2022-06-22T00:00:00</td>
#       <td id="T_3d002_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_3d002_row1_col10" class="data row1 col10" >Tendring</td>
#       <td id="T_3d002_row1_col11" class="data row1 col11" >51.857536</td>
#       <td id="T_3d002_row1_col12" class="data row1 col12" >1.278721</td>
#       <td id="T_3d002_row1_col13" class="data row1 col13" >20</td>
#       <td id="T_3d002_row1_col14" class="data row1 col14" >15</td>
#       <td id="T_3d002_row1_col15" class="data row1 col15" >30</td>
#       <td id="T_3d002_row1_col16" class="data row1 col16" >100.000000</td>
#     </tr>
#     <tr>
#       <td id="T_3d002_row2_col0" class="data row2 col0" >Melrose Hotel</td>
#       <td id="T_3d002_row2_col1" class="data row2 col1" >Hotel/bed & breakfast/guest house</td>
#       <td id="T_3d002_row2_col2" class="data row2 co

# %% [markdown]
# ### **Display Worst Hygiene Establishments' Locations**

# %%
pandasx.display_dataframe_hvplot \
    (worst_hygiene_locations_dataframe, 'Figure 2.1.1: Worst Hygiene Establishments',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (-1.0, 1.5), y_limit_float_tuple = (50.7, 52.2),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
pandasx.display_dataframe_hvplot \
    (worst_hygiene_locations_dataframe, 'Figure 2.1.2: Worst Hygiene Establishments (Close-Up)',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (-0.05, 0.2), y_limit_float_tuple = (51.45, 51.6),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.2 -- Which establishments in London have a high rating value greater than or equal to 4 (1-5)?**

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
# These lines of code query and display the number of establishments in London where the 'RatingValue' 
# field has a value greater than or equal to 4.
query_dictionary = {'LocalAuthorityName': {'$regex': 'London'}, 'RatingValue': {'$gte':4}}

establishments_count_integer = establishments_pymongo_collection.count_documents(query_dictionary)

logx.print_and_log_text \
    ('\033[1mThere are {:,} establishments with a rating value greater than or equal to 4.\033[0m' \
        .format(establishments_count_integer))
# Out:
# There are 33 establishments with a rating value greater than or equal to 4.

# %% [markdown]
# ### **Display First Document**

# %%
# This query returns all the documents where the establishment is in London and the 'RatingValue' field 
# has a value greater than or equal to 4.
query_results_dictionary_list = establishments_pymongo_collection.find(query_dictionary)

# This line of code displays the first document from the query results.
pprint(query_results_dictionary_list[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('662f2efc371bdca4d9e9c249'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %% [markdown]
# ### **High Rating Value, London Establishments Data Set**

# %%
# This line of code creates the dataframe.
high_rating_london_dataframe = pd.DataFrame(list(query_results_dictionary_list))

# This function rearranges the columns in the dataframe.
high_rating_london_dataframe \
    = restaurant_analysisx.rearrange_establishments_dataframe_columns(high_rating_london_dataframe)

logx.log_write_object(high_rating_london_dataframe)

# %% [markdown]
# ### **Number of Rows in High Rating Value, London Data Set**

# %%
logx.print_and_log_text \
    ('\033[1mThe number of rows in the High Rating Value, London DataFrame is {:,}.\033[0m' \
        .format(len(high_rating_london_dataframe)))
# Out:
# The number of rows in the High Rating Value, London DataFrame is 33.

# %% [markdown]
# ### **High Rating Value, London Establishments' Locations Data Set**

# %%
high_rating_london_locations_dataframe \
    = restaurant_analysisx.return_locations_dataframe(high_rating_london_dataframe, 'RatingValue', 50.0)

logx.log_write_object(high_rating_london_locations_dataframe)

# %% [markdown]
# ### **Display High Rating Value, London Establishments**

# %%
pandasx.return_formatted_table \
    (high_rating_london_locations_dataframe, 
     'Table 2.2: High Rating Value, London Establishments') \
        .format({'RatingValue': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_92b44 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_92b44_row0_col0, #T_92b44_row0_col1, #T_92b44_row0_col2, #T_92b44_row0_col3, #T_92b44_row0_col4, #T_92b44_row0_col5, #T_92b44_row0_col6, #T_92b44_row0_col7, #T_92b44_row0_col8, #T_92b44_row0_col9, #T_92b44_row0_col10, #T_92b44_row0_col11, #T_92b44_row0_col12, #T_92b44_row0_col13, #T_92b44_row0_col14, #T_92b44_row0_col15, #T_92b44_row0_col16, #T_92b44_row1_col0, #T_92b44_row1_col1, #T_92b44_row1_col2, #T_92b44_row1_col3, #T_92b44_row1_col4, #T_92b44_row1_col5, #T_92b44_row1_col6, #T_92b44_row1_col7, #T_92b44_row1_col8, #T_92b44_row1_col9, #T_92b44_row1_col10, #T_92b44_row1_col11, #T_92b44_row1_col12, #T_92b44_row1_col13, #T_92b44_row1_col14, #T_92b44_row1_col15, #T_92b44_row1_col16, #T_92b44_row2_col0, #T_92b44_row2_col1, #T_92b44_row2_col2, #T_92b44_row2_col3, #T_92b44_row2_col4, #T_92b44_row2_col5, #T_92b44_row2_col6, #T_92b44_row2_col7, #T_92b44_row2_col8, #T_92b44_row2_col9, #T_92b44_row2_col10, #T_92b44_row2_col11, #T_92b44_row2_col12, #T_92b44_row2_col13, #T_92b44_row2_col14, #T_92b44_row2_col15, #T_92b44_row2_col16, #T_92b44_row3_col0, #T_92b44_row3_col1, #T_92b44_row3_col2, #T_92b44_row3_col3, #T_92b44_row3_col4, #T_92b44_row3_col5, #T_92b44_row3_col6, #T_92b44_row3_col7, #T_92b44_row3_col8, #T_92b44_row3_col9, #T_92b44_row3_col10, #T_92b44_row3_col11, #T_92b44_row3_col12, #T_92b44_row3_col13, #T_92b44_row3_col14, #T_92b44_row3_col15, #T_92b44_row3_col16, #T_92b44_row4_col0, #T_92b44_row4_col1, #T_92b44_row4_col2, #T_92b44_row4_col3, #T_92b44_row4_col4, #T_92b44_row4_col5, #T_92b44_row4_col6, #T_92b44_row4_col7, #T_92b44_row4_col8, #T_92b44_row4_col9, #T_92b44_row4_col10, #T_92b44_row4_col11, #T_92b44_row4_col12, #T_92b44_row4_col13, #T_92b44_row4_col14, #T_92b44_row4_col15, #T_92b44_row4_col16, #T_92b44_row5_col0, #T_92b44_row5_col1, #T_92b44_row5_col2, #T_92b44_row5_col3, #T_92b44_row5_col4, #T_92b44_row5_col5, #T_92b44_row5_col6, #T_92b44_row5_col7, #T_92b44_row5_col8, #T_92b44_row5_col9, #T_92b44_row5_col10, #T_92b44_row5_col11, #T_92b44_row5_col12, #T_92b44_row5_col13, #T_92b44_row5_col14, #T_92b44_row5_col15, #T_92b44_row5_col16, #T_92b44_row6_col0, #T_92b44_row6_col1, #T_92b44_row6_col2, #T_92b44_row6_col3, #T_92b44_row6_col4, #T_92b44_row6_col5, #T_92b44_row6_col6, #T_92b44_row6_col7, #T_92b44_row6_col8, #T_92b44_row6_col9, #T_92b44_row6_col10, #T_92b44_row6_col11, #T_92b44_row6_col12, #T_92b44_row6_col13, #T_92b44_row6_col14, #T_92b44_row6_col15, #T_92b44_row6_col16, #T_92b44_row7_col0, #T_92b44_row7_col1, #T_92b44_row7_col2, #T_92b44_row7_col3, #T_92b44_row7_col4, #T_92b44_row7_col5, #T_92b44_row7_col6, #T_92b44_row7_col7, #T_92b44_row7_col8, #T_92b44_row7_col9, #T_92b44_row7_col10, #T_92b44_row7_col11, #T_92b44_row7_col12, #T_92b44_row7_col13, #T_92b44_row7_col14, #T_92b44_row7_col15, #T_92b44_row7_col16, #T_92b44_row8_col0, #T_92b44_row8_col1, #T_92b44_row8_col2, #T_92b44_row8_col3, #T_92b44_row8_col4, #T_92b44_row8_col5, #T_92b44_row8_col6, #T_92b44_row8_col7, #T_92b44_row8_col8, #T_92b44_row8_col9, #T_92b44_row8_col10, #T_92b44_row8_col11, #T_92b44_row8_col12, #T_92b44_row8_col13, #T_92b44_row8_col14, #T_92b44_row8_col15, #T_92b44_row8_col16, #T_92b44_row9_col0, #T_92b44_row9_col1, #T_92b44_row9_col2, #T_92b44_row9_col3, #T_92b44_row9_col4, #T_92b44_row9_col5, #T_92b44_row9_col6, #T_92b44_row9_col7, #T_92b44_row9_col8, #T_92b44_row9_col9, #T_92b44_row9_col10, #T_92b44_row9_col11, #T_92b44_row9_col12, #T_92b44_row9_col13, #T_92b44_row9_col14, #T_92b44_row9_col15, #T_92b44_row9_col16 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_92b44">
#   <caption>Table 2.2: High Rating Value, London Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_92b44_level0_col0" class="col_heading level0 col0" >BusinessName</th>
#       <th id="T_92b44_level0_col1" class="col_heading level0 col1" >BusinessType</th>
#       <th id="T_92b44_level0_col2" class="col_heading level0 col2" >AddressLine1</th>
#       <th id="T_92b44_level0_col3" class="col_heading level0 col3" >AddressLine2</th>
#       <th id="T_92b44_level0_col4" class="col_heading level0 col4" >AddressLine3</th>
#       <th id="T_92b44_level0_col5" class="col_heading level0 col5" >AddressLine4</th>
#       <th id="T_92b44_level0_col6" class="col_heading level0 col6" >PostCode</th>
#       <th id="T_92b44_level0_col7" class="col_heading level0 col7" >RatingValue</th>
#       <th id="T_92b44_level0_col8" class="col_heading level0 col8" >RatingDate</th>
#       <th id="T_92b44_level0_col9" class="col_heading level0 col9" >NewRatingPending</th>
#       <th id="T_92b44_level0_col10" class="col_heading level0 col10" >LocalAuthorityName</th>
#       <th id="T_92b44_level0_col11" class="col_heading level0 col11" >Latitude</th>
#       <th id="T_92b44_level0_col12" class="col_heading level0 col12" >Longitude</th>
#       <th id="T_92b44_level0_col13" class="col_heading level0 col13" >Hygiene</th>
#       <th id="T_92b44_level0_col14" class="col_heading level0 col14" >Structural</th>
#       <th id="T_92b44_level0_col15" class="col_heading level0 col15" >ConfidenceInManagement</th>
#       <th id="T_92b44_level0_col16" class="col_heading level0 col16" >MarkerSize</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_92b44_row0_col0" class="data row0 col0" >Charlie's</td>
#       <td id="T_92b44_row0_col1" class="data row0 col1" >Other catering premises</td>
#       <td id="T_92b44_row0_col2" class="data row0 col2" >Oak Apple Farm Building 103 Sheernes Docks</td>
#       <td id="T_92b44_row0_col3" class="data row0 col3" >Sheppy Kent</td>
#       <td id="T_92b44_row0_col4" class="data row0 col4" ></td>
#       <td id="T_92b44_row0_col5" class="data row0 col5" ></td>
#       <td id="T_92b44_row0_col6" class="data row0 col6" >ME12</td>
#       <td id="T_92b44_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_92b44_row0_col8" class="data row0 col8" >2021-10-18T00:00:00</td>
#       <td id="T_92b44_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_92b44_row0_col10" class="data row0 col10" >City of London Corporation</td>
#       <td id="T_92b44_row0_col11" class="data row0 col11" >51.369321</td>
#       <td id="T_92b44_row0_col12" class="data row0 col12" >0.508551</td>
#       <td id="T_92b44_row0_col13" class="data row0 col13" >5</td>
#       <td id="T_92b44_row0_col14" class="data row0 col14" >10</td>
#       <td id="T_92b44_row0_col15" class="data row0 col15" >5</td>
#       <td id="T_92b44_row0_col16" class="data row0 col16" >200.000000</td>
#     </tr>
#     <tr>
#       <td id="T_92b44_row1_col0" class="data row1 col0" >Mv City Cruises Erasmus</td>
#       <td id="T_92b44_row1_col1" class="data row1 col1" >Other catering premises</td>
#       <td id="T_92b44_row1_col2" class="data row1 col2" >Cherry Garden Pier</td>
#       <td id="T_92b44_row1_col3" class="data row1 col3" >Cherry Garden Street Rotherhithe</td>
#       <td id="T_92b44_row1_col4" class="data row1 col4" >Charlton</td>
#       <td id="T_92b44_row1_col5" class="data row1 col5" ></td>
#       <td id="T_92b44_row1_col6" class="data row1 col6" >TN4 8HR</td>
#       <td id="T_92b44_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_92b44_row1_col8" class="data row1 col8" >2021-05-14T00:00:00</td>
#       <td id="T_92b44_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_92b44_row1_col10" class="data row1 col10" >City of London Corporation</td>
#       <td id="T_92b44_row1_col11" class="data row1 col11" >51.123623</td>
#       <td id="T_92b44_row1_col12" class="data row1 col12" >0.249256</td>
#       <td id="T_92b44_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_92b44_row1_col14" class="data row1 col14" >5</td>
#       <td id="T_92b44_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_92b44_row1_col16" class="data row1 col16" >250.000000</td>
#     </tr>
#     <tr>
#       <td id="T_92b44_row2_col0" class="data row2 col0" >Benfleet Motor Yacht Club</td>
#       <td id="T_92b44_row2_col1" class="data ro

# %% [markdown]
# ### **Display High Rating Value, London Establishments' Locations**

# %%
pandasx.display_dataframe_hvplot \
    (high_rating_london_locations_dataframe, 'Figure 2.2.1: High Rating Value, London',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (-1.0, 1.5), y_limit_float_tuple = (50.7, 52.2),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
pandasx.display_dataframe_hvplot \
    (high_rating_london_locations_dataframe, 'Figure 2.2.2: High Rating Value, London (Close-Up)',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (0.0, 0.1), y_limit_float_tuple = (51.49, 51.54),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.3 -- What are the top 5 establishments with a rating value of 5, sorted by best hygiene score, nearest to the new restaurant added, "Penang Flavours?**

# %% [markdown]
# ### **Penang Flavours' Latitude and Longitude**

# %%
# This line of code retrieves the Penang Flavours's document fields, 'latitude' and 'longitude'.
penang_flavours_coordinates_dictionary \
    = establishments_pymongo_collection.find_one \
        ({'BusinessName':'Penang Flavours'}, ['geocode.longitude', 'geocode.latitude'])

# This line of code extracts the Penang Flavours's 'longitude' field value.
longitude_float = penang_flavours_coordinates_dictionary['geocode']['longitude']

# This line of code extracts the Penang Flavours's 'latitude' field value.
latitude_float = penang_flavours_coordinates_dictionary['geocode']['latitude']

# %% [markdown]
# ### **Query Search Range Variables**

# %%
# This line of code establishes the search range as ±0.01 degrees.
degree_search_float = 0.01

# These lines of code calculate and assign the minimum and maximum longitude.
minimum_longitude_float = longitude_float - degree_search_float

maximum_longitude_float = longitude_float + degree_search_float

# These lines of code calculate and assign the minimum and maximum latitude.
minimum_latitude_float = latitude_float - degree_search_float

maximum_latitude_float = latitude_float + degree_search_float

# %% [markdown]
# ### **Query Results**

# %%
# These dictionaries are the query parameters.
query_dictionary \
    = {'RatingValue': 5,
       'geocode.longitude': {'$gte': minimum_longitude_float, '$lte': maximum_longitude_float},
       'geocode.latitude': {'$gte': minimum_latitude_float, '$lte': maximum_latitude_float}}
       
sort_values_tuple_list = [('scores.Hygiene', 1)]
       
limit_integer = 5


# This query returns the top 5 establishments with a 'RatingValue' field value of 5, sorted 
# by lowest hygiene score, nearest to the restaurant, 'Penang Flavours'.
query_results_list \
    = list(establishments_pymongo_collection \
               .find(query_dictionary) \
               .sort(sort_values_tuple_list) \
               .limit(limit_integer))

logx.log_write_object(query_results_list)

# %% [markdown]
# ### **Number of Establishments from `count_documents`**

# %%
establishments_count_integer \
    = establishments_pymongo_collection.count_documents(query_dictionary, limit = limit_integer)

logx.print_and_log_text \
    ('\033[1m' \
     + 'Due to the query parameter limiting the number of results, ' \
     + 'there are {:,} establishments with a rating value of 5.' \
            .format(establishments_count_integer) \
     + '\033[0m')
# Out:
# Due to the query parameter limiting the number of results, there are 5 establishments with a rating value of 5.

# %% [markdown]
# ### **Display All Documents**

# %%
pprint(query_results_list)
# Out:
# [{'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('662f2efc371bdca4d9ea0070'),
#   'geocode': {'latitude': 51.4875335693359, 'longitude': 0.0925370007753372},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '35 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Atlantic Fish Bar',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4646.974611855838,
#   'FHRSID': 694478,
#   'LocalAuthorityBusinessID': 'PI/000086506',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PR',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('662f2efc371bdca4d9ea00a8'),
#   'geocode': {'latitude': 51.4867296, 'longitude': 0.0912164},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694478',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('662f2efc371bdca4d9ea00a5'),
#   'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('662f2efc371bdca4d9ea0060'),
#   'geocode': {'latitude': 51.4871482849121, 'longitude': 0.0924199968576431},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('662f2efc371bdca4d9ea008d'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %% [markdown]
# ### Highest Rating, Best Hygiene Establishments Data Set**

# %%
# This line of code creates the dataframe.
high_rating_best_hygiene_dataframe = pd.DataFrame(query_results_list)

# This function rearranges the columns in the dataframe.
high_rating_best_hygiene_dataframe \
    = restaurant_analysisx.rearrange_establishments_dataframe_columns(high_rating_best_hygiene_dataframe)

logx.log_write_object(high_rating_best_hygiene_dataframe)

# %% [markdown]
# ### **Number of Rows in Highest Rating, Best Hygiene Establishments Data Set**

# %%
logx.print_and_log_text \
    ('\033[1mThe number of rows in the Highest Rating, Best Hygiene DataFrame is {:,}.\033[0m' \
        .format(len(high_rating_best_hygiene_dataframe)))
# Out:
# The number of rows in the Highest Rating, Best Hygiene DataFrame is 5.

# %% [markdown]
# ### **Highest Rating, Best Hygiene Establishments' Locations Data Set**

# %%
high_rating_london_locations_dataframe \
    = restaurant_analysisx.return_locations_dataframe \
        (high_rating_best_hygiene_dataframe, 'RatingValue', 50.0)

logx.log_write_object(high_rating_london_locations_dataframe)

# %% [markdown]
# ### **Display Highest Rating, Best Hygiene Establishments**

# %%
# This line of code displays a formatted DataFrame hiding those columns that are not necessary 
# for editorial decisions.
pandasx.return_formatted_table \
    (high_rating_london_locations_dataframe, 
     'Table 2.3: Highest Rating, Best Hygiene Establishments') \
        .format({'RatingValue': '{:,.0f}'})
# Out:
# <style type="text/css">
# #T_81225 caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_81225_row0_col0, #T_81225_row0_col1, #T_81225_row0_col2, #T_81225_row0_col3, #T_81225_row0_col4, #T_81225_row0_col5, #T_81225_row0_col6, #T_81225_row0_col7, #T_81225_row0_col8, #T_81225_row0_col9, #T_81225_row0_col10, #T_81225_row0_col11, #T_81225_row0_col12, #T_81225_row0_col13, #T_81225_row0_col14, #T_81225_row0_col15, #T_81225_row0_col16, #T_81225_row1_col0, #T_81225_row1_col1, #T_81225_row1_col2, #T_81225_row1_col3, #T_81225_row1_col4, #T_81225_row1_col5, #T_81225_row1_col6, #T_81225_row1_col7, #T_81225_row1_col8, #T_81225_row1_col9, #T_81225_row1_col10, #T_81225_row1_col11, #T_81225_row1_col12, #T_81225_row1_col13, #T_81225_row1_col14, #T_81225_row1_col15, #T_81225_row1_col16, #T_81225_row2_col0, #T_81225_row2_col1, #T_81225_row2_col2, #T_81225_row2_col3, #T_81225_row2_col4, #T_81225_row2_col5, #T_81225_row2_col6, #T_81225_row2_col7, #T_81225_row2_col8, #T_81225_row2_col9, #T_81225_row2_col10, #T_81225_row2_col11, #T_81225_row2_col12, #T_81225_row2_col13, #T_81225_row2_col14, #T_81225_row2_col15, #T_81225_row2_col16, #T_81225_row3_col0, #T_81225_row3_col1, #T_81225_row3_col2, #T_81225_row3_col3, #T_81225_row3_col4, #T_81225_row3_col5, #T_81225_row3_col6, #T_81225_row3_col7, #T_81225_row3_col8, #T_81225_row3_col9, #T_81225_row3_col10, #T_81225_row3_col11, #T_81225_row3_col12, #T_81225_row3_col13, #T_81225_row3_col14, #T_81225_row3_col15, #T_81225_row3_col16, #T_81225_row4_col0, #T_81225_row4_col1, #T_81225_row4_col2, #T_81225_row4_col3, #T_81225_row4_col4, #T_81225_row4_col5, #T_81225_row4_col6, #T_81225_row4_col7, #T_81225_row4_col8, #T_81225_row4_col9, #T_81225_row4_col10, #T_81225_row4_col11, #T_81225_row4_col12, #T_81225_row4_col13, #T_81225_row4_col14, #T_81225_row4_col15, #T_81225_row4_col16 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_81225">
#   <caption>Table 2.3: Highest Rating, Best Hygiene Establishments</caption>
#   <thead>
#     <tr>
#       <th id="T_81225_level0_col0" class="col_heading level0 col0" >BusinessName</th>
#       <th id="T_81225_level0_col1" class="col_heading level0 col1" >BusinessType</th>
#       <th id="T_81225_level0_col2" class="col_heading level0 col2" >AddressLine1</th>
#       <th id="T_81225_level0_col3" class="col_heading level0 col3" >AddressLine2</th>
#       <th id="T_81225_level0_col4" class="col_heading level0 col4" >AddressLine3</th>
#       <th id="T_81225_level0_col5" class="col_heading level0 col5" >AddressLine4</th>
#       <th id="T_81225_level0_col6" class="col_heading level0 col6" >PostCode</th>
#       <th id="T_81225_level0_col7" class="col_heading level0 col7" >RatingValue</th>
#       <th id="T_81225_level0_col8" class="col_heading level0 col8" >RatingDate</th>
#       <th id="T_81225_level0_col9" class="col_heading level0 col9" >NewRatingPending</th>
#       <th id="T_81225_level0_col10" class="col_heading level0 col10" >LocalAuthorityName</th>
#       <th id="T_81225_level0_col11" class="col_heading level0 col11" >Latitude</th>
#       <th id="T_81225_level0_col12" class="col_heading level0 col12" >Longitude</th>
#       <th id="T_81225_level0_col13" class="col_heading level0 col13" >Hygiene</th>
#       <th id="T_81225_level0_col14" class="col_heading level0 col14" >Structural</th>
#       <th id="T_81225_level0_col15" class="col_heading level0 col15" >ConfidenceInManagement</th>
#       <th id="T_81225_level0_col16" class="col_heading level0 col16" >MarkerSize</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_81225_row0_col0" class="data row0 col0" >Howe and Co Fish and Chips - Van 17</td>
#       <td id="T_81225_row0_col1" class="data row0 col1" >Mobile caterer</td>
#       <td id="T_81225_row0_col2" class="data row0 col2" >Restaurant And Premises 107A Plumstead High Street</td>
#       <td id="T_81225_row0_col3" class="data row0 col3" ></td>
#       <td id="T_81225_row0_col4" class="data row0 col4" >Plumstead</td>
#       <td id="T_81225_row0_col5" class="data row0 col5" >Greenwich</td>
#       <td id="T_81225_row0_col6" class="data row0 col6" >SE18 1SE</td>
#       <td id="T_81225_row0_col7" class="data row0 col7" >5</td>
#       <td id="T_81225_row0_col8" class="data row0 col8" >2021-11-11T00:00:00</td>
#       <td id="T_81225_row0_col9" class="data row0 col9" >False</td>
#       <td id="T_81225_row0_col10" class="data row0 col10" >Greenwich</td>
#       <td id="T_81225_row0_col11" class="data row0 col11" >51.487534</td>
#       <td id="T_81225_row0_col12" class="data row0 col12" >0.092537</td>
#       <td id="T_81225_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_81225_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_81225_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_81225_row0_col16" class="data row0 col16" >250.000000</td>
#     </tr>
#     <tr>
#       <td id="T_81225_row1_col0" class="data row1 col0" >Atlantic Fish Bar</td>
#       <td id="T_81225_row1_col1" class="data row1 col1" >Takeaway/sandwich shop</td>
#       <td id="T_81225_row1_col2" class="data row1 col2" >35 Lakedale Road</td>
#       <td id="T_81225_row1_col3" class="data row1 col3" ></td>
#       <td id="T_81225_row1_col4" class="data row1 col4" >Plumstead</td>
#       <td id="T_81225_row1_col5" class="data row1 col5" >Greenwich</td>
#       <td id="T_81225_row1_col6" class="data row1 col6" >SE18 1PR</td>
#       <td id="T_81225_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_81225_row1_col8" class="data row1 col8" >2021-06-16T00:00:00</td>
#       <td id="T_81225_row1_col9" class="data row1 col9" >False</td>
#       <td id="T_81225_row1_col10" class="data row1 col10" >Greenwich</td>
#       <td id="T_81225_row1_col11" class="data row1 col11" >51.486730</td>
#       <td id="T_81225_row1_col12" class="data row1 col12" >0.091216</td>
#       <td id="T_81225_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_81225_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_81225_row1_col15" class="data row1 col15" >5</td>
#       <td id="T_81225_row1_col16" class="data row1 col16" >250.000000</td>
#     </tr>
#     <tr>
#       <td id="T_81225_row2_col0" class="data row2 col0" >Plumstead Manor Nursery</td>
#       <td id="T_81225_row2_col1" class="data row2 col1" >Caring Premises</td>
#       <td id="T_81225_row2_col2" class="data row2 col2" >Plumstead Manor School Old Mill Road</td>
#       <td id="T_81225_row2_col3" class="data row2 col3" ></td>
#       <td id="T_81225_row2_col4" class="data row2 col4" >Plumstead</td>
#       <td id="T_81225_row2_col5" class="data row2 col5" >Greenwich</td>
#       <td id="T_81225_row2_col6" class="data row2 col6" >SE18 1QG</td>
#       <td id="T_81225_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_81225_row2_col8" class="data row2 col8" >2021-06-16T00:00:00</td>
#       <td id="T_81225_row2_col9" class="data row2 col9" >False</td>
#       <td id="T_81225_row2_col10" class="data row2 col10" >Greenwich</td>
#       <td id="T_81225_row2_col11" class="data row2 col11" >51.481518</td>
#       <td id="T_81225_row2_col12" class="data row2 col12" >0.085994</td>
#       <td id="T_81225_row2_col13" class="data row2 col13" >0</td>
#       <td id="T_81225_row2_col14" class="data row2 col14" >0</td>
#       <td id="T_81225_row2_col15" class="data row2 col15" >5</td>
#       <td id="T_81225_row2_col16" class="data row2 col16" >250.000000</td>
#     </tr>
#     <tr>
#       <td id="T_81225_row3_col0" class="data row3 col0" >Iceland</td>
#       <td id="T_81225_row3_col1" class="data row3 col1" >Retailers - supermarkets/hypermarkets</td>
#       <td id="T_81225_row3_col2" class="data row3 col2" >144 - 146 Plumstead High Street</td>
#       <td id="T_81225_row3_col3" class="data row3 col3" ></td>
#       <td id="T_81225_row3_col4" class="data row3 col4" >Plumstead</td>
#       <td id="T_81225_row3_col5" class="data row3 col5" >Greenwich</td>
#       <td id="T_81225_row3_col6" class="data row3 col6" >SE18 1JQ</td>
#       <td id="T_81225_row3_col7" class="data row3 col7" >5</td>
#       <td id="T_81225_

# %% [markdown]
# ### **Display Highest Rating, Best Hygiene Establishments' Locations**

# %%
pandasx.display_dataframe_hvplot \
    (high_rating_london_locations_dataframe, 'Figure 2.3.1: Highest Rating, Best Hygiene',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (-1.0, 1.5), y_limit_float_tuple = (50.7, 52.2),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %%
pandasx.display_dataframe_hvplot \
    (high_rating_london_locations_dataframe, 'Figure 2.3.2: Highest Rating, Best Hygiene (Close-Up)',
     'BusinessName', 'MarkerSize', 'Longitude', 'Latitude',
     x_limit_float_tuple = (0.08, 0.10), y_limit_float_tuple = (51.48, 51.49),
     hover_columns_string_list = hover_columns_string_list)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (BusinessName,MarkerSize,AddressLine2,LocalAuthorityName)

# %% [markdown]
# ## **2.4 -- How many establishments in each Local Authority area have a hygiene score of 0 (the best possible rating)? Sort the number of establishments from highest to lowest, and print out the top ten local authority areas.**

# %% [markdown]
# ### **Aggregation Query Parameters**

# %%
# 1. This Dictionary matches establishments with a hygiene score of 0.
match_query_dictionary = {'$match': {'scores.Hygiene': 0}}

# 2. This Dictionary groups the matches by Local Authority and counts how many establishments 
# meet the match criteria for each Local Authority.
group_query_dictionary = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}}}

# 3. This Dictionary sorts the matches in descending order (from highest to lowest) based on count.
sort_values_dictionary \
    = {'$sort': {'count': -1}}

pipeline_dictionary_list = [match_query_dictionary, group_query_dictionary, sort_values_dictionary]

# %% [markdown]
# ### **Aggregation Query Results**

# %%
aggregate_query_results_dictionary_list \
    = list(establishments_pymongo_collection.aggregate(pipeline_dictionary_list))

logx.log_write_object(aggregate_query_results_dictionary_list)

# %% [markdown]
# ### **Number of Authorities and Establishments from Aggregation Query Results**

# %%
authority_count_integer \
    = len([element for element in aggregate_query_results_dictionary_list if isinstance(element, dict)])

establishments_count_integer \
    = sum([element['count'] for element in aggregate_query_results_dictionary_list if isinstance(element, dict)])

logx.print_and_log_text \
    ('\033[1m' \
     + 'From the aggregation query results, there are {:,} establishments with a hygiene score of 0 '\
        .format(establishments_count_integer)
     + 'in {:,} Local Authorities.' \
        .format(authority_count_integer) \
     + '\033[0m')
# Out:
# From the aggregation query results, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### **Number of Authorities and Establishments from `count_documents`**

# %%
authority_count_integer \
    = len(establishments_pymongo_collection.distinct('LocalAuthorityName', {'scores.Hygiene': 0}))

establishments_count_integer \
    = establishments_pymongo_collection.count_documents({'scores.Hygiene': 0})

logx.print_and_log_text \
    ('\033[1m' \
     + "From the 'count_documents' method, there are {:,} " \
        .format(establishments_count_integer)
     + 'establishments with a hygiene score of 0 in {:,} Local Authorities.' \
        .format(authority_count_integer) \
     + '\033[0m')
# Out:
# From the 'count_documents' method, there are 16,827 establishments with a hygiene score of 0 in 55 Local Authorities.

# %% [markdown]
# ### **Display Documents**

# %%
pprint(aggregate_query_results_dictionary_list[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %% [markdown]
# ### **Highest Hygiene Establishments Data Set**

# %%
highest_hygiene_score_dataframe = pd.DataFrame(aggregate_query_results_dictionary_list)

highest_hygiene_score_dataframe.rename \
    (columns = {'_id': 'LocalAuthorityName', 'count': 'Count'}, inplace = True)

logx.log_write_object(highest_hygiene_score_dataframe)

# %% [markdown]
# ### **Number of Rows in Highest Hygiene Establishments Data Set**

# %%
logx.print_and_log_text \
    ('\033[1m' \
     + 'The number of rows in the Highest Hygiene DataFrame is {:,}.' \
        .format(len(highest_hygiene_score_dataframe)) \
     + '\033[0m')
# Out:
# The number of rows in the Highest Hygiene DataFrame is 55.

# %% [markdown]
# ### **Display Highest Hygiene Establishments**

# %%
pandasx.return_formatted_table \
    (highest_hygiene_score_dataframe, 
     'Table 2.4: Local Authorities with Number of Establishments with Highest Hygiene Score')
# Out:
# <style type="text/css">
# #T_375af caption {
#   color: black;
#   font-size: 20px;
#   font-style: bold;
#   text-align: center;
# }
# #T_375af_row0_col0, #T_375af_row0_col1, #T_375af_row1_col0, #T_375af_row1_col1, #T_375af_row2_col0, #T_375af_row2_col1, #T_375af_row3_col0, #T_375af_row3_col1, #T_375af_row4_col0, #T_375af_row4_col1, #T_375af_row5_col0, #T_375af_row5_col1, #T_375af_row6_col0, #T_375af_row6_col1, #T_375af_row7_col0, #T_375af_row7_col1, #T_375af_row8_col0, #T_375af_row8_col1, #T_375af_row9_col0, #T_375af_row9_col1 {
#   text-align: center;
#   border: 1.3px solid red;
#   color: blue;
# }
# </style>
# <table id="T_375af">
#   <caption>Table 2.4: Local Authorities with Number of Establishments with Highest Hygiene Score</caption>
#   <thead>
#     <tr>
#       <th id="T_375af_level0_col0" class="col_heading level0 col0" >LocalAuthorityName</th>
#       <th id="T_375af_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_375af_row0_col0" class="data row0 col0" >Thanet</td>
#       <td id="T_375af_row0_col1" class="data row0 col1" >1,130</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row1_col0" class="data row1 col0" >Greenwich</td>
#       <td id="T_375af_row1_col1" class="data row1 col1" >882</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row2_col0" class="data row2 col0" >Maidstone</td>
#       <td id="T_375af_row2_col1" class="data row2 col1" >713</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row3_col0" class="data row3 col0" >Newham</td>
#       <td id="T_375af_row3_col1" class="data row3 col1" >711</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row4_col0" class="data row4 col0" >Swale</td>
#       <td id="T_375af_row4_col1" class="data row4 col1" >686</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row5_col0" class="data row5 col0" >Chelmsford</td>
#       <td id="T_375af_row5_col1" class="data row5 col1" >680</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row6_col0" class="data row6 col0" >Medway</td>
#       <td id="T_375af_row6_col1" class="data row6 col1" >672</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row7_col0" class="data row7 col0" >Bexley</td>
#       <td id="T_375af_row7_col1" class="data row7 col1" >607</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row8_col0" class="data row8 col0" >Southend-On-Sea</td>
#       <td id="T_375af_row8_col1" class="data row8 col1" >586</td>
#     </tr>
#     <tr>
#       <td id="T_375af_row9_col0" class="data row9 col0" >Tendring</td>
#       <td id="T_375af_row9_col1" class="data row9 col1" >542</td>
#     </tr>
#   </tbody>
# </table>

# %%
# logx.end_program()
